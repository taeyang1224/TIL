# %% [markdown]
# # 규칙 만들기

# %% [markdown]
# ## IF
# - 조건을 만들 때 사용하는 함수
# - `IF(조건식, 참 값, 거짓 값)` 형식으로 사용
# - 주로 SELECT절에 사용하는 함수, 결과 값을 새로운 컬럼으로 반환
#
# ## IFNULL
# - 데이터가 NULL인지 아닌지를 확인해 NULL이라면 새로운 값을 반환하는 함수
# - `IFNULL([컬럼], NULL일 때 값)` 형식으로 사용
# - 해당 컬럼의 값이 NULL인 로우에서 NULL일 때 값을 반환
# - 주로 SELECT절에 사용하는 함수, 결과 값을 새로운 컬럼으로 반환
#
# ## CASE
# - 주로 SELECT절에 사용하는 함수, 결과값을 **새로운 컬럼**으로 반환
# - ELSE 문장을 생략 시 NULL 값을 반환
# ![image.png](attachment:image.png)
#
# ## 함수 만들기
# ![image-2.png](attachment:image-2.png)
